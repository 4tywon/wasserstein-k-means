# %%
from image_ops import Dataset_Operations
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
from clustering import k_means
data = np.load("synthetic_data/ribosome/ribosome_clean.npy")

# %%
from skimage.transform import rescale
def rescale_data(image_stack, desired_size):
    scaling_constant = desired_size/image_stack.shape[1]
    images = []
    for image in image_stack:
        images.append(rescale(image, scaling_constant))
    return np.asarray(images)
noise = np.random.normal(0, 7, data.shape)
data = rescale_data(data + noise, 128)
# fakes = np.abs(np.random.normal(0, 0.001, (500, 128, 128)))

# %%
def psf(size):
    x_idx = np.array([i for i in range(101)]) - 0.5*101
    y_idx = np.array([i for i in range(101)]) - 0.5*101
    xx, yy = np.meshgrid(x_idx, y_idx, sparse=True)
    r = np.sqrt(xx**2 + yy**2)
    kernel = np.sin(100*r)*np.exp(-0.6*r)
    kernel = ndimage.zoom(kernel, size/101)
    return kernel
kernel = psf(101)[40:61, 41:61]
plt.imshow(kernel)

# %%
from scipy import signal
full_data = data #np.vstack((data,fakes))
plt.imshow(full_data[8])
plt.show()
plt.imshow(signal.convolve2d(full_data[8], kernel,mode='valid', ))
plt.show()

# %%
ctf_data = []
for image in full_data:
    ctf_data.append(signal.convolve2d(image, kernel,mode='valid'))
ctf_data = np.array(ctf_data)

# %%
plt.imshow(ctf_data[4])
# Out:
# (4001, 108, 109)

# %%
dataset = Dataset_Operations(ctf_data[:4000, :, :108], metric='l2')
clustering = k_means(40, 100)
clustering.train(dataset, niter=3, init='k++')
# Out:
# 100%|██████████| 39/39 [21:14<00:00, 31.58s/it]
#   0%|          | 0/40 [00:00<?, ?it/s]
# [1776, 2845, 3962, 1927, 138, 3231, 125, 3886, 3383, 1980, 3621, 2564, 55, 2835, 2803, 313, 2621, 3849, 559, 1986, 1795, 3927, 3312, 146, 2433, 301, 61, 2151, 3996, 274, 2962, 3746, 3339, 2872, 1161, 1803, 1414, 2319, 838, 2421]
# 100%|██████████| 40/40 [20:54<00:00, 31.41s/it]
#  20%|██        | 8/40 [04:03<16:15, 30.49s/it]
# -------------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-14-53010b6ebad3> in <module>
#       1 dataset = Dataset_Operations(ctf_data[:4000, :, :108], metric='l2')
#       2 clustering = k_means(40, 100)
# ----> 3 clustering.train(dataset, niter=3, init='k++')
#
# ~/Projects/wasserstein-k-means/clustering.py in train(self, image_metric_space, niter, init)
#      35             for i, center in enumerate(tqdm(self.centers)):
#      36                 for j, angle in enumerate(self.angles):
# ---> 37                     dist = image_metric_space.batch_distance_to(ndimage.rotate(center, angle, reshape=False))
#      38                     distances[:, i, j] = dist
#      39             min_distance_idxs = distances.reshape(image_metric_space.n, self.k * len(self.angles)).argmin(axis=1)
#
# ~/Projects/wasserstein-k-means/image_ops.py in batch_distance_to(self, image)
#      15     def batch_distance_to(self, image):
#      16         if self.metric == 'l2':
# ---> 17             return np.sqrt(((self.images - image)**2).sum(axis = 2).sum(axis = 1))
#      18
#      19         elif self.metric == 'wemd':
#
# KeyboardInterrupt:

# %%
clustering.view_centers()

# %%
from skimage.util import montage

# %%
dataset2 = Dataset_Operations(ctf_data[:4000, :, :108], metric='wemd')
clustering2 = k_means(40, 100)
clustering2.train(dataset2,niter=5, init='k++')
# Out:
# /usr/local/lib/python3.7/site-packages/pywt/_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
#
#   0%|          | 0/39 [00:00<?, ?it/s]
#   3%|▎         | 1/39 [01:43<1:05:27, 103.35s/it]
#   5%|▌         | 2/39 [03:28<1:04:09, 104.03s/it]
#   8%|▊         | 3/39 [05:11<1:02:11, 103.66s/it]
#  10%|█         | 4/39 [06:55<1:00:23, 103.54s/it]
#  13%|█▎        | 5/39 [08:38<58:39, 103.50s/it]
#  15%|█▌        | 6/39 [10:21<56:53, 103.44s/it]
#  18%|█▊        | 7/39 [12:04<55:06, 103.32s/it]
#  21%|██        | 8/39 [13:48<53:25, 103.39s/it]
#  23%|██▎       | 9/39 [15:31<51:41, 103.38s/it]
#  26%|██▌       | 10/39 [17:16<50:06, 103.66s/it]
#  28%|██▊       | 11/39 [19:00<48:27, 103.85s/it]
#  31%|███       | 12/39 [20:44<46:48, 104.03s/it]
#  33%|███▎      | 13/39 [22:33<45:41, 105.43s/it]
#  36%|███▌      | 14/39 [24:22<44:25, 106.60s/it]

# %%
clustering2.view_centers()

# %%
for c in clustering2.centers:
    plt.imshow(c)
    plt.show()

# %%
for i in set(clustering.labels[4002:].tolist()):
    print(int(i))

# %%
[int(i) for i in set(clustering2.labels[4002:].tolist())]

# %%
labels = clustering2.labels
centers = clustering2.centers
counts = dict()
for label in labels:
    counts[label] = counts[label] + 1 if label in counts else 1
counts = [(label, counts[label]) for label in counts]
center_counts = [(centers[int(label[0])], label[1]) for label in counts]
sorted_centers = sorted(center_counts, key=lambda x:x[1], reverse=True)
sorted_centers = [c[0] for c in sorted_centers]
fig, ax = plt.subplots(figsize=(30, 30))
ax.imshow(montage(np.array(sorted_centers)))
plt.show()
counts = sorted(counts, key=lambda x:x[1], reverse=True)
sorted_labels = np.zeros(len(labels))
for i, entry in enumerate(counts):
    sorted_labels[labels == entry[0]] = i
labels = sorted_labels

plt.hist(labels, bins=40)
plt.show()

# %%
idx = np.array([i for i in range(4501)])
cluster = idx[labels == 6]
cluster[cluster <= 4001]

# %%
sorted_centers

# %%
x = np.zeros((10,10))
x[2:4,2:4] = 0.5
y = np.zeros((10,10))
y[2:4,2:4] = 1
# ims = np.array([x,y])
plt.imshow(montage(ims, rescale_intensity=True))

# %%
from scipy import ndimage
cms  = []
for image in data:
    cm = ndimage.measurements.center_of_mass(image)
    cms.append(cm[0])
    cms.append(cm[1])

# %%
real =  np.load("raw_ribosome_data.npy")

# %%
from scipy import signal
freqs, psd = signal.welch(real[10].reshape(129600))

plt.figure(figsize=(5, 4))
plt.semilogx(freqs, psd)
plt.title('PSD: power spectral density')
plt.xlabel('Frequency')
plt.ylabel('Power')
plt.tight_layout()
